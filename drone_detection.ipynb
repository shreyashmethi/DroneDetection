# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# INFO:yolov5:YOLOv5 🚀 v6.2-214-g6db0fac Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
# YOLOv5 🚀 v6.2-214-g6db0fac Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 22.9/166.8 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pafy youtube_dl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.9 MB 8.3 MB/s
# ...

# %%
import pafy
import youtube_dl

# %%
# !python detect.py --weights "/content/drive/MyDrive/best.pt" --img 640 --conf 0.25 --source '/content/drive/MyDrive/unv.mp4'
# Out:
# detect: weights=['/content/drive/MyDrive/best.pt'], source=/content/drive/MyDrive/unv.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-211-g32a9218 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 267 layers, 46108278 parameters, 0 gradients, 107.6 GFLOPs
# video 1/1 (1/6781) /content/drive/MyDrive/unv.mp4: 384x640 1 Drone, 35.2ms
# video 1/1 (2/6781) /content/drive/MyDrive/unv.mp4: 384x640 1 Drone, 35.0ms
# video 1/1 (3/6781) /content/drive/MyDrive/unv.mp4: 384x640 1 Drone, 34.9ms
# video 1/1 (4/6781) /content/drive/MyDrive/unv.mp4: 384x640 1 Drone, 35.1ms
# ...

# %%
# !python train.py --img 640 --batch 4 --epochs 25 --data /content/custom_training.yaml --weights yolov5l.pt --cache
# Out:
# train: weights=yolov5l.pt, cfg=, data=/content/custom_training.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=25, batch_size=4, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-214-g6db0fac Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 1280 --batch 4 --epochs 25 --data /content/custom_training.yaml --weights yolov5l.pt --cache
# Out:
# train: weights=yolov5l.pt, cfg=, data=/content/custom_training.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=25, batch_size=4, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-214-g6db0fac Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python train.py --img 1280 --batch 4 --epochs 25 --data /content/custom_training.yaml --weights yolov5x.pt --cache
# Out:
# train: weights=yolov5x.pt, cfg=, data=/content/custom_training.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=25, batch_size=4, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-214-g6db0fac Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python train.py --img 1280 --batch 4 --epochs 25 --data /content/custom_training.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/custom_training.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=25, batch_size=4, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-214-g6db0fac Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python train.py --img 1280 --batch 4 --epochs 25 --data /content/custom_training.yaml --weights yolov5m.pt --cache
# Out:
# train: weights=yolov5m.pt, cfg=, data=/content/custom_training.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=25, batch_size=4, imgsz=1280, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-214-g6db0fac Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !zip -r runs1.zip /content/yolov5/runs/train/exp5
# Out:
#   adding: content/yolov5/runs/train/exp5/ (stored 0%)
#   adding: content/yolov5/runs/train/exp5/events.out.tfevents.1666980907.d8b0bb0af490.3052.0 (deflated 57%)
#   adding: content/yolov5/runs/train/exp5/val_batch1_pred.jpg (deflated 9%)
#   adding: content/yolov5/runs/train/exp5/val_batch2_pred.jpg (deflated 9%)
#   adding: content/yolov5/runs/train/exp5/train_batch0.jpg (deflated 13%)
#   adding: content/yolov5/runs/train/exp5/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp5/weights/best.pt (deflated 8%)
#   adding: content/yolov5/runs/train/exp5/weights/last.pt (deflated 8%)
#   adding: content/yolov5/runs/train/exp5/F1_curve.png (deflated 16%)
#   adding: content/yolov5/runs/train/exp5/val_batch0_pred.jpg (deflated 12%)
#   adding: content/yolov5/runs/train/exp5/R_curve.png (deflated 17%)
#   adding: content/yolov5/runs/train/exp5/val_batch2_labels.jpg (deflated 9%)
#   adding: content/yolov5/runs/train/exp5/confusion_matrix.png (deflated 38%)
# ...

# %%
import shutil
shutil.copy('/content/yolov5/runs1.zip', '/content/drive/MyDrive/' )
# Out:
# '/content/drive/MyDrive/runs1.zip'
